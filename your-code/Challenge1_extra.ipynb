# %%
import json
import requests as req
import os
from dotenv import load_dotenv

# %%
with open ("../pass.txt", "r") as file:

    pass_ = file.read()

HEADER = {"Authorization": "token " + pass_}

# %%
# Entrada a ironhack madrid
url = 'https://api.github.com/orgs/Ironhack-Data-Madrid-Octubre-2023'
repos = req.get(url, headers = HEADER)
repos
# Out:
# <Response [200]>

# %%
# Keys Iron hack madrid
repos.json().keys()
# Out:
# dict_keys(['login', 'id', 'node_id', 'url', 'repos_url', 'events_url', 'hooks_url', 'issues_url', 'members_url', 'public_members_url', 'avatar_url', 'description', 'name', 'company', 'blog', 'location', 'email', 'twitter_username', 'is_verified', 'has_organization_projects', 'has_repository_projects', 'public_repos', 'public_gists', 'followers', 'following', 'html_url', 'created_at', 'updated_at', 'archived_at', 'type'])

# %%
repos.json()['repos_url']
# Out:
# 'https://api.github.com/orgs/Ironhack-Data-Madrid-Octubre-2023/repos'

# %%
# Entrada a la lista de repos 
url = 'https://api.github.com/orgs/Ironhack-Data-Madrid-Octubre-2023/repos'
repos = req.get(url, headers = HEADER)
repos
# Out:
# <Response [200]>

# %%
for i in range(len(repos.json())):
    lab = repos.json()[i]['name']
    print(lab)
# Out:
# 1.1-lab_bash
# 1.1-lab_git
# 1.2-lab_list_comprehension
# 1.2-lab_tuple_set_dict
# 1.3-lab_bags_of_words
# 1.3-lab_functions
# 1.4-lab_errorhand_listcomp
# 1.4-lab_map_reduce_filter
# 1.5-lab_vikings
# 2.1-lab_intro_pandas
# 2.1-lab_numpy
# 2.2-lab_import_export
# 2.2-lab_pandas_deepdive
# 2.3-lab_df_calculation_and_transformation
# 2.4-lab_data_cleaning
# 3.1-lab_intro_to_mysql
# 3.2-lab_mysql_select
# 3.3-lab_mysql_advanced
# 3.4-lab_mongo
# 4.1-lab-parsing-api
# 4.1-lab_api_scavengers_game
# apuntes_clase
# w2-project_pandas
# w3-project_SQL
# pull_requests_instructions
# soluciones_labs

# %%
# Entrada a repo individual
url = 'https://api.github.com/repos/Ironhack-Data-Madrid-Octubre-2023/' + '1.1-lab_bash'
repos = req.get(url, headers = HEADER)
repos.json().keys()
# Out:
# dict_keys(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'has_discussions', 'forks_count', 'mirror_url', 'archived', 'disabled', 'ope
# ...

# %%
repos.json()['forks_url']
# Out:
# 'https://api.github.com/repos/Ironhack-Data-Madrid-Octubre-2023/1.1-lab_bash/forks'

# %%
url = 'https://api.github.com/repos/Ironhack-Data-Madrid-Octubre-2023/1.1-lab_bash/forks'
repos = req.get(url, headers = HEADER)
repos.json()[20]['language']

# %%
# Entrada a la lista de repos 
url = 'https://api.github.com/orgs/Ironhack-Data-Madrid-Octubre-2023/repos'
repos = req.get(url, headers = HEADER)
repos

for i in range(len(repos.json())):
    lab = repos.json()[i+10]['name']
    print(lab)
    
    try:
        url = f'https://api.github.com/repos/Ironhack-Data-Madrid-Octubre-2023/' + lab
        repos = req.get(url, headers = HEADER)
        forks = repos.json()['forks_url']
        print(forks)

        url = forks
        repos = req.get(url , headers = HEADER)

        for i in range(len(repos.json())):
            print(repos.json()[i]['language'])
    except:
        print("NOMBRE MAL INGRESADO")
        continue
# Out:
# 2.1-lab_numpy
# https://api.github.com/repos/Ironhack-Data-Madrid-Octubre-2023/2.1-lab_numpy/forks
# Python
# Jupyter Notebook
# Jupyter Notebook
# Python
# Jupyter Notebook
# Python
# Jupyter Notebook
# Jupyter Notebook
# Python
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Python
# Jupyter Notebook
# Python
# Python
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Python
# Python
# Jupyter Notebook
# Jupyter Notebook
# Python
# Python
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# 2.1-lab_numpy
# https://api.github.com/repos/Ironhack-Data-Madrid-Octubre-2023/2.1-lab_numpy/forks
# Python
# Jupyter Notebook
# Jupyter Notebook
# Python
# Jupyter Notebook
# Python
# Jupyter Notebook
# Jupyter Notebook
# Python
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Python
# Jupyter Notebook
# Python
# Python
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Python
# ...
